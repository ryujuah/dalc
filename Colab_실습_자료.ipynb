# %% [markdown]
# <a href="https://colab.research.google.com/github/ryujuah/dalc/blob/main/Colab_%EC%8B%A4%EC%8A%B5_%EC%9E%90%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab 실습 하기
# # 1.마크다운으로 내 깃허브 링크 삽입하기
# https://github.com/ryujuah/dalc

# %% [markdown]
# # 2.마크다운으로 이미지 삽입하기
# ![KakaoTalk_20210306_140429292_02.jpg](data:image/jpeg;base64,...)

# %%
![](https://search.pstatic.net/sunny/?src=https%3A%2F%2Fi.pinimg.com%2Foriginals%2Fde%2Fb0%2Ff3%2Fdeb0f35934ada97889a11dea313fc819.jpg&type=sc960_832)

# %% [markdown]
# ## 3. To do List
# - 학교수업열심히 듣기
# - 어떻게 하는지 잘몰라서 헤맸다...

# %%
1.
